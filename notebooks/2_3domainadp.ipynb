# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.append(str(PROJECT_ROOT / "scripts"))
from domadp import run

adapted_df = run()
# Out:
# ...
# DOMAIN ADAPTATION
# ...
#
# Loading speech features...
# Dataset shape: (10322, 51)
# Features: 45
#
# Dataset distribution:
# dataset
# CREMA-D    7442
# RAVDESS    2880
# Name: count, dtype: int64
#
# ...
# BEFORE CORAL
# ...
# Domain classification accuracy: 1.0
#
# Classification report:
#               precision    recall  f1-score   support
#
#      CREMA-D       1.00      1.00      1.00      1489
#      RAVDESS       1.00      1.00      1.00       576
#
#     accuracy                           1.00      2065
#    macro avg       1.00      1.00      1.00      2065
# weighted avg       1.00      1.00      1.00      2065
#
#
# ...
# CORAL ALIGNMENT
# ...
# CREMA-D samples: 7442
# RAVDESS samples: 2880
#
# Performing CORAL alignment...
# CORAL alignment complete.
#
# ...
# AFTER CORAL
# ...
# Domain classification accuracy: 1.0
#
# Classification report:
#               precision    recall  f1-score   support
#
#      CREMA-D       1.00      1.00      1.00      1489
#      RAVDESS       1.00      1.00      1.00       576
# ...
